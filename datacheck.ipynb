# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('meter_data.csv')
#df.head(1000)

# %%
df.shape
# Out:
# (14400000, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14400000 entries, 0 to 14399999
# Data columns (total 27 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   meter_id                   object
#  1   phase_type                 object
#  2   timestamp                  object
#  3   v1                         float64
#  4   v2                         float64
#  5   v3                         float64
#  6   i1                         float64
#  7   i2                         float64
#  8   i3                         float64
#  9   v_agg                      float64
#  10  i_agg                      float64
#  11  power_factor               float64
#  12  energy_consumed_kwh        float64
#  13  expected_energy_kwh        float64
#  14  signal_strength_dbm        float64
#  15  data_transmitted           int64
#  16  tamper_flag                int64
#  17  fault_flag                 int64
#  18  meter_status               object
# ...

# %%
df.describe()
#df.describe(include='all')
# Out:
#                  v1            v2            v3            i1            i2  \
# count  7.215120e+06  7.215120e+06  7.215120e+06  7.215120e+06  7.215120e+06
# mean   2.299949e+02  2.300033e+02  2.299917e+02  1.500211e+01  1.499908e+01
# std    1.000274e+01  9.998316e+00  1.000089e+01  5.001488e+00  4.999890e+00
# min    1.778601e+02  1.800621e+02  1.778609e+02 -9.480595e+00 -9.108052e+00
# 25%    2.232487e+02  2.232598e+02  2.232531e+02  1.162957e+01  1.162519e+01
# 50%    2.299943e+02  2.300038e+02  2.299948e+02  1.500138e+01  1.499874e+01
# 75%    2.367432e+02  2.367525e+02  2.367336e+02  1.837741e+01  1.837311e+01
# max    2.796795e+02  2.805431e+02  2.850153e+02  4.086039e+01  4.122505e+01
#
#                  i3         v_agg         i_agg  power_factor  \
# count  7.215120e+06  1.440000e+07  1.440000e+07  1.440000e+07
# mean   1.500037e+01  2.299981e+02  1.250569e+01  8.995605e-01
# std    4.999777e+00  8.163123e+00  3.861645e+00  4.899088e-02
# ...

# %%
df1 =pd.read_csv('daily_meter_summary.csv')
df1.head(10)
# Out:
#        meter_id location_id        date  energy_consumed_kwh_sum  \
# 0  EKEDC_000001      Agbara  2025-03-21                    68.48
# 1  EKEDC_000001      Agbara  2025-03-22                   400.96
# 2  EKEDC_000001      Agbara  2025-03-23                   579.01
# 3  EKEDC_000001      Agbara  2025-03-24                   314.15
# 4  EKEDC_000001      Agbara  2025-03-25                   781.98
# 5  EKEDC_000001      Agbara  2025-03-26                   483.71
# 6  EKEDC_000001      Agbara  2025-03-27                     9.29
# 7  EKEDC_000001      Agbara  2025-03-28                   405.26
# 8  EKEDC_000001      Agbara  2025-03-29                   172.84
# 9  EKEDC_000001      Agbara  2025-03-30                    15.20
#
#    expected_energy_kwh_sum  expected_energy_pf_calc_sum  \
# 0                    81.97                     1.791132
# 1                   443.89                     7.297382
# 2                   570.25                     5.492529
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6392320 entries, 0 to 6392319
# Data columns (total 33 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   meter_id                     object
#  1   location_id                  object
#  2   date                         object
#  3   energy_consumed_kwh_sum      float64
#  4   expected_energy_kwh_sum      float64
#  5   expected_energy_pf_calc_sum  float64
#  6   total_vended_amount_sum      float64
#  7   revenue_loss_sum             float64
#  8   energy_loss_kwh_sum          float64
#  9   energy_loss_flag_sum         int64
#  10  fault_flag_sum               int64
#  11  tamper_flag_sum              int64
#  12  uptime_flag_sum              int64
#  13  supply_voltage_flag_sum      int64
#  14  pf_delta_mean                float64
#  15  v_agg_mean                   float64
#  16  v_agg_min                    float64
#  17  v_agg_max                    float64
# ...

# %%
df1.shape
# Out:
# (6392320, 33)
